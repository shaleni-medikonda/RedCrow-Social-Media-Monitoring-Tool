# %%
import tweepy
import csv
import pandas as pd
consumer_key = "hjnl0NymVIF8br8Y2EX9sSA1Z"
consumer_secret = "1RMtpx4vtmADZnUgESLwEDz8ShQ3wzLLY7sdiK952aExicBIzY"
access_token = "2713337750-S860lpgAU2rq1icBm7TZ7aGkrRJa3M9gbXfZXT2"
access_token_secret = "sUI3RO03Pcc1SV8K0w0VLGMycrgUvX5l8QBW87DtPvf2T"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
main_tweet = []
#Change username below to different twitter handles to get their tweets.
username = 'CenterlineBio'
search_tweets = api.user_timeline(id=username,count=3000,tweet_mode='extended')
for tweet in search_tweets:
    if 'retweeted_status' in tweet._json:
        print(tweet._json['retweeted_status']['full_text'])
        main_tweet.append((tweet.created_at,tweet._json['retweeted_status']['full_text']))
    else:
        print(tweet.full_text)
        main_tweet.append((tweet.created_at,tweet.full_text))
# Out:
# Surgical navigation startup wins fourth small business award from NIH's National Heart, Lung, and Blood Institute to extend novel technology to address peripheral vascular disease https://t.co/y6MMqBguWQ
# FDA-cleared 3D Endovascular Guiding System to be launched and highlighted at the VEITHsymposium https://t.co/zO3b4JvMIu
# Centerline Biomedical's Intra-Operative Positioning System Technology Showcased at VIVA Disruptive Technologies Session https://t.co/l2TEcacpXz
# Centerline Biomedical Announces Philip D. Rackliffe, MBA as Chief Executive Officer (CEO) Effective October 21st, 2019 https://t.co/TT0rxhAzjr
# Centerline Biomedical Announces Philip D. Rackliffe, MBA as Chief Executive Officer (CEO) Effective October 21st, 2019 https://t.co/AFADozAJVy https://t.co/gyvrxcyaHE
# ...

# %%
#main_tweet below is your input for sentiment. All tweets are appended here.
main_tweet
# Out:
# [(datetime.datetime(2020, 4, 22, 12, 14, 40),
#   "Surgical navigation startup wins fourth small business award from NIH's National Heart, Lung, and Blood Institute to extend novel technology to address peripheral vascular disease https://t.co/y6MMqBguWQ"),
#  (datetime.datetime(2019, 11, 18, 17, 8, 28),
#   'FDA-cleared 3D Endovascular Guiding System to be launched and highlighted at the VEITHsymposium https://t.co/zO3b4JvMIu'),
#  (datetime.datetime(2019, 11, 12, 14, 40, 26),
#   "Centerline Biomedical's Intra-Operative Positioning System Technology Showcased at VIVA Disruptive Technologies Session https://t.co/l2TEcacpXz"),
#  (datetime.datetime(2019, 10, 22, 18, 40, 7),
#   'Centerline Biomedical Announces Philip D. Rackliffe, MBA as Chief Executive Officer (CEO) Effective October 21st, 2019 https://t.co/TT0rxhAzjr'),
#  (datetime.datetime(2019, 10, 21, 19, 46, 15),
# ...

# %%
myFile = open('/Users/Knight/Desktop/Capstone/CenterlineBio.xls', 'w')
with myFile:
   writer = csv.writer(myFile)
   writer.writerows(main_tweet)
